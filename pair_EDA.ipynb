# %%
import pandas as pd
data = pd.read_csv('world-data-2023_part1.csv')

# %% [markdown]
# # Ejercicios de exploración del conjunto de datos
#
#     Muestra las primeras 5 filas del conjunto de datos.
#
#     Muestra las últimas 5 filas del conjunto de datos.
#
#     Muestra una muestra aleatoria de 5 filas del conjunto de datos.
#
#     Muestra el nombre de todas las columnas en el conjunto de datos.
#
#     Muestra los valores únicos en la columna "Abbreviation".

# %%
#primeras 5
data.head(5)
# Out:
#    Unnamed: 0      Country Density\n(P/Km2) Abbreviation  \
# 0           0  Afghanistan               60           AF
# 1           1      Albania              105           AL
# 2           2      Algeria               18           DZ
# 3           3      Andorra              164           AD
# 4           4       Angola               26           AO
#
#   Agricultural Land( %) Land Area(Km2) Armed Forces size  Birth Rate  \
# 0                58.10%        652,230           323,000       32.49
# 1                43.10%         28,748             9,000       11.78
# 2                17.40%      2,381,741           317,000       24.28
# 3                40.00%            468               NaN        7.20
# 4                47.50%      1,246,700           117,000       40.73
#
#    Calling Code Capital/Major City Co2-Emissions     CPI CPI Change (%)  \
# 0          93.0              Kabul         8,672   149.9          2.30%
# 1         355.0             Tirana         4,536  119.05          1.40%
# 2         213.0            Algiers       150,006  151.36          2.00%
# 3         376.0   Andorra la Vella           469     NaN            NaN
# 4         244.0             Luanda        34,693  261.73         17.10%
#
#   Currency-Code  Fertility Rate Forested Area (%) Gasoline Price
# 0           AFN            4.47             2.10%         $0.70
# 1           ALL            1.62            28.10%         $1.36
# 2           DZD            3.02             0.80%         $0.28
# 3           EUR            1.27            34.00%         $1.51
# 4           AOA            5.52            46.30%         $0.97

# %%
# 10 ultimas
data.tail(5)
# Out:
#      Unnamed: 0    Country Density\n(P/Km2) Abbreviation  \
# 190         190  Venezuela               32           VE
# 191         191    Vietnam              314           VN
# 192         192      Yemen               56           YE
# 193         193     Zambia               25           ZM
# 194         194   Zimbabwe               38           ZW
#
#     Agricultural Land( %) Land Area(Km2) Armed Forces size  Birth Rate  \
# 190                24.50%        912,050           343,000       17.88
# 191                39.30%        331,210           522,000       16.75
# 192                44.60%        527,968            40,000       30.45
# 193                32.10%        752,618            16,000       36.19
# 194                41.90%        390,757            51,000       30.68
#
#      Calling Code Capital/Major City Co2-Emissions       CPI CPI Change (%)  \
# 190          58.0            Caracas       164,175  2,740.27        254.90%
# 191          84.0              Hanoi       192,668    163.52          2.80%
# 192         967.0              Sanaa        10,609    157.58          8.10%
# 193         260.0             Lusaka         5,141    212.31          9.20%
# 194         263.0             Harare        10,983    105.51          0.90%
#
#     Currency-Code  Fertility Rate Forested Area (%) Gasoline Price
# 190           VED            2.27            52.70%         $0.00
# 191           VND            2.05            48.10%         $0.80
# 192           YER            3.79             1.00%         $0.92
# 193           ZMW            4.63            65.20%         $1.40
# 194           NaN            3.62            35.50%         $1.34

# %%
#5 filas aleatorias
data.sample(5)
# Out:
#      Unnamed: 0    Country Density\n(P/Km2) Abbreviation  \
# 95           95    Lesotho               71           LS
# 37           37   Colombia               46           CO
# 148         148      Samoa               70           WS
# 93           93     Latvia               30           LV
# 8             8  Australia                3           AU
#
#     Agricultural Land( %) Land Area(Km2) Armed Forces size  Birth Rate  \
# 95                 77.60%         30,355             2,000       26.81
# 37                 40.30%      1,138,910           481,000       14.88
# 148                12.40%          2,831               NaN       24.38
# 93                 31.10%         64,589             6,000       10.00
# 8                  48.20%      7,741,220            58,000       12.60
#
#      Calling Code Capital/Major City Co2-Emissions     CPI CPI Change (%)  \
# 95          266.0             Maseru         2,512  155.86          5.20%
# 37           57.0             Bogot�        97,814  140.95          3.50%
# 148         685.0               Apia           246  117.56          1.00%
# 93          371.0               Riga         7,004  116.86          2.80%
# 8            61.0           Canberra       375,908   119.8          1.60%
#
#     Currency-Code  Fertility Rate Forested Area (%) Gasoline Price
# 95            NaN            3.14             1.60%         $0.70
# 37            COP            1.81            52.70%         $0.68
# 148           WST            3.88            60.40%         $0.91
# 93            EUR            1.60            54.00%         $1.16
# 8             AUD            1.74            16.30%         $0.93

# %%
# nombre columns
data.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Density\n(P/Km2)', 'Abbreviation',
#        'Agricultural Land( %)', 'Land Area(Km2)', 'Armed Forces size',
#        'Birth Rate', 'Calling Code', 'Capital/Major City', 'Co2-Emissions',
#        'CPI', 'CPI Change (%)', 'Currency-Code', 'Fertility Rate',
#        'Forested Area (%)', 'Gasoline Price'],
#       dtype='object')

# %%
data['Abbreviation'].unique()
# Out:
# array(['AF', 'AL', 'DZ', 'AD', 'AO', 'AG', 'AR', 'AM', 'AU', 'AT', 'AZ',
#        'BS', 'BH', 'BD', 'BB', 'BY', 'BE', 'BZ', 'BJ', 'BT', 'BO', 'BA',
#        'BW', 'BR', 'BN', 'BG', 'BF', 'BI', 'CI', 'CV', 'KH', 'CM', 'CA',
#        'CF', 'TD', 'CL', 'CN', 'CO', 'KM', nan, 'CR', 'HR', 'CU', 'CY',
#        'CZ', 'CD', 'DK', 'DJ', 'DM', 'DO', 'EC', 'EG', 'SV', 'GQ', 'ER',
#        'EE', 'ET', 'FJ', 'FI', 'FR', 'GA', 'GM', 'GE', 'DE', 'GH', 'GR',
#        'GD', 'GT', 'GN', 'GW', 'GY', 'HT', 'HN', 'HU', 'IS', 'IN', 'ID',
#        'IR', 'IQ', 'IL', 'IT', 'JM', 'JP', 'JO', 'KZ', 'KE', 'KI', 'KW',
#        'KG', 'LA', 'LV', 'LB', 'LS', 'LR', 'LY', 'LI', 'LT', 'LU', 'MG',
#        'MW', 'MY', 'MV', 'ML', 'MT', 'MH', 'MR', 'MU', 'MX', 'FM', 'MD',
#        'MC', 'MN', 'ME', 'MA', 'MZ', 'MM', 'NR', 'NP', 'NL', 'NZ', 'NI',
#        'NE', 'NG', 'KP', 'NO', 'OM', 'PK', 'PW', 'PA', 'PG', 'PY', 'PE',
#        'PH', 'PL', 'PT', 'QA', 'RO', 'RU', 'RW', 'KN', 'LC', 'VC', 'WS',
#        'SM', 'ST', 'SA', 'SN', 'RS', 'SC', 'SL', 'SG', 'SK', 'SI', 'SB',
#        'SO', 'ZA', 'KR', 'SS', 'ES', 'LK', 'SD', 'SR', 'SE', 'CH', 'SY',
#        'TJ', 'TZ', 'TH', 'TL', 'TG', 'TO', 'TT', 'TN', 'TR', 'TM', 'TV',
#        'UG', 'UA', 'AE', 'GB', 'US', 'UY', 'UZ', 'VU', 'VE', 'VN', 'YE',
#        'ZM', 'ZW'], dtype=object)

# %% [markdown]
# # BONUS DE EXPLORACION
#
#     Cuenta cuántas veces aparece cada valor único en la columna "Abbreviation".
#
#     Verifica si hay valores nulos en el conjunto de datos.
#
#     Verifica si hay valores no nulos en el conjunto de datos.
#
#     Muestra información general sobre el conjunto de datos.
#
#     Elimina una columna específica (por ejemplo, "Armed Forces size").
#
#     Selecciona las columnas numéricas del conjunto de datos y muestra sus estadísticas descriptivas básicas (para esto tendréis que usar el método '.describe(), su documentación la tenéis aquí).

# %%
data['Abbreviation'].value_counts()
# Out:
# Abbreviation
# AF    1
# PY    1
# NE    1
# NG    1
# KP    1
#      ..
# GR    1
# GD    1
# GT    1
# GN    1
# ZW    1
# Name: count, Length: 188, dtype: int64

# %%
#nulos
data.isnull().sum()
# Out:
# Unnamed: 0                0
# Country                   0
# Density\n(P/Km2)          0
# Abbreviation              7
# Agricultural Land( %)     7
# Land Area(Km2)            1
# Armed Forces size        24
# Birth Rate                6
# Calling Code              1
# Capital/Major City        3
# Co2-Emissions             7
# CPI                      17
# CPI Change (%)           16
# Currency-Code            15
# Fertility Rate            7
# Forested Area (%)         7
# Gasoline Price           20
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Unnamed: 0               195
# Country                  195
# Density\n(P/Km2)         195
# Abbreviation             188
# Agricultural Land( %)    188
# Land Area(Km2)           194
# Armed Forces size        171
# Birth Rate               189
# Calling Code             194
# Capital/Major City       192
# Co2-Emissions            188
# CPI                      178
# CPI Change (%)           179
# Currency-Code            180
# Fertility Rate           188
# Forested Area (%)        188
# Gasoline Price           175
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             195 non-null    int64
#  1   Country                195 non-null    object
#  2   Density
# (P/Km2)        195 non-null    object
#  3   Abbreviation           188 non-null    object
#  4   Agricultural Land( %)  188 non-null    object
#  5   Land Area(Km2)         194 non-null    object
#  6   Armed Forces size      171 non-null    object
#  7   Birth Rate             189 non-null    float64
#  8   Calling Code           194 non-null    float64
#  9   Capital/Major City     192 non-null    object
#  10  Co2-Emissions          188 non-null    object
#  11  CPI                    178 non-null    object
#  12  CPI Change (%)         179 non-null    object
#  13  Currency-Code          180 non-null    object
#  14  Fertility Rate         188 non-null    float64
#  15  Forested Area (%)      188 non-null    object
#  16  Gasoline Price         175 non-null    object
# dtypes: float64(3), int64(1), object(13)
# memory usage: 26.0+ KB

# %%
#drop column
data.drop(columns=['Armed Forces size'], axis =1, inplace = True)

# %%
#columnas numericas
data.select_dtypes(include=['int'])
# Out:
#      Unnamed: 0
# 0             0
# 1             1
# 2             2
# 3             3
# 4             4
# ..          ...
# 190         190
# 191         191
# 192         192
# 193         193
# 194         194
#
# [195 rows x 1 columns]

# %%
data.describe().T
# Out:
#                 count        mean         std   min     25%      50%  \
# Unnamed: 0      195.0   97.000000   56.435804  0.00  48.500   97.000
# Birth Rate      189.0   20.214974    9.945774  5.90  11.300   17.950
# Calling Code    194.0  360.546392  323.236419  1.00  82.500  255.500
# Fertility Rate  188.0    2.698138    1.282267  0.98   1.705    2.245
#
#                      75%      max
# Unnamed: 0      145.5000   194.00
# Birth Rate       28.7500    46.08
# Calling Code    506.7500  1876.00
# Fertility Rate    3.5975     6.91

# %% [markdown]
# # Ejercicios con loc e iloc
#
#     Selecciona todas las columnas de las filas 2 a 4 (inclusive) utilizando loc.
#
#     Utilizando loc, filtra el conjunto de datos para mostrar solo las filas donde la densidad (columna "Birth Rate") es mayor a 30.
#
#     Utilizando loc selecciona las columnas "Country" y "Capital/Major City" de las filas donde el porcentaje de tierra agrícola (columna "Fertility Rate") es superior al 3.
#
#     Selecciona todas las filas de las columnas 0 a 4 (excluyendo la columna 4) utilizando iloc.
#
#     Encuentra el valor en la fila 2 y columna 7 utilizando iloc.
#
#     Selecciona todas las filas para las columnas 0, 2, y 5 utilizando iloc.

# %%
data.loc[2:4, :]
# Out:
#    Unnamed: 0  Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 2           2  Algeria               18           DZ                17.40%
# 3           3  Andorra              164           AD                40.00%
# 4           4   Angola               26           AO                47.50%
#
#   Land Area(Km2)  Birth Rate  Calling Code Capital/Major City Co2-Emissions  \
# 2      2,381,741       24.28         213.0            Algiers       150,006
# 3            468        7.20         376.0   Andorra la Vella           469
# 4      1,246,700       40.73         244.0             Luanda        34,693
#
#       CPI CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 2  151.36          2.00%           DZD            3.02             0.80%
# 3     NaN            NaN           EUR            1.27            34.00%
# 4  261.73         17.10%           AOA            5.52            46.30%
#
#   Gasoline Price
# 2         $0.28
# 3         $1.51
# 4         $0.97

# %%
data.loc[data['Birth Rate'] > 30]
# Out:
#      Unnamed: 0                           Country Density\n(P/Km2)  \
# 0             0                       Afghanistan               60
# 4             4                            Angola               26
# 18           18                             Benin              108
# 26           26                      Burkina Faso               76
# 27           27                           Burundi              463
# 28           28                       Ivory Coast               83
# 31           31                          Cameroon               56
# 33           33          Central African Republic                8
# 34           34                              Chad               13
# 38           38                           Comoros              467
# 39           39             Republic of the Congo               16
# 45           45  Democratic Republic of the Congo               40
# 53           53                 Equatorial Guinea               50
# 54           54                           Eritrea               35
# 57           57                          Ethiopia              115
# 61           61                             Gabon                9
# 62           62                        The Gambia              239
# 69           69                            Guinea               53
# 70           70                     Guinea-Bissau               70
# 96           96                           Liberia               53
# 101         101                        Madagascar               48
# 102         102                            Malawi              203
# 105         105                              Mali               17
# 108         108                        Mauritania                5
# 117         117                        Mozambique               40
# 125         125                             Niger               19
# 126         126                           Nigeria              226
# 144         144                            Rwanda              525
# 150         150                      S�����������              228
# 152         152                           Senegal               87
# 155         155                      Sierra Leone              111
# 159         159                   Solomon Islands               25
# 160         160                           Somalia               25
# 163         163                       South Sudan               18
# 166         166                             Sudan               25
# 171         171                        Tajikistan               68
# 172         172                          Tanzania               67
# 175         175                              Togo              152
# 182         182                            Uganda              229
# 192         192                             Yemen               56
# 193         193                            Zambia               25
# 194         194                          Zimbabwe               38
#
#     Abbreviation Agricultural Land( %) Land Area(Km2)  Birth Rate  \
# 0             AF                58.10%        652,230       32.49
# 4             AO                47.50%      1,246,700       40.73
# 18            BJ                33.30%        112,622       36.22
# 26            BF                44.20%        274,200       37.93
# 27            BI                79.20%         27,830       39.01
# 28            CI                64.80%        322,463       35.74
# 31            CM                20.60%        475,440       35.39
# 33            CF                 8.20%        622,984       35.35
# 34            TD                39.70%      1,284,000       42.17
# 38            KM                71.50%          2,235       31.88
# 39           NaN                31.10%        342,000       32.86
# 45            CD                11.60%      2,344,858       41.18
# 53            GQ                10.10%         28,051       33.24
# 54            ER                75.20%        117,600       30.30
# 57            ET                36.30%      1,104,300       32.34
# 61            GA                20.00%        267,667       31.61
# 62            GM                59.80%         11,300       38.54
# 69            GN                59.00%        245,857       36.36
# 70            GW                58.00%         36,125       35.13
# 96            LR                28.00%        111,369       33.04
# 101           MG                71.20%        587,041       32.66
# 102           MW                61.40%        118,484       34.12
# 105           ML                33.80%      1,240,192       41.54
# 108           MR                38.50%      1,030,700       33.69
# 117           MZ                63.50%        799,380       37.52
# 125           NE                36.10%      1,267,000       46.08
# 126           NG                77.70%        923,768       37.91
# 144           RW                73.40%         26,338       31.70
# 150           ST                50.70%            964       31.54
# 152           SN                46.10%        196,722       34.52
# 155           SL                54.70%         71,740       33.41
# 159           SB                 3.90%         28,896       32.44
# 160           SO                70.30%        637,657       41.75
# 163           SS                   NaN        644,329       35.01
# 166           SD                28.70%      1,861,484       32.18
# 171           TJ                34.10%        144,100       30.76
# 172           TZ                44.80%        947,300       36.70
# 175           TG                70.20%         56,785       33.11
# 182           UG                71.90%        241,038       38.14
# 192           YE                44.60%        527,968       30.45
# 193           ZM                32.10%        752,618       36.19
# 194           ZW                41.90%        390,757       30.68
#
#      Calling Code Capital/Major City Co2-Emissions       CPI CPI Change (%)  \
# 0            93.0              Kabul         8,672     149.9          2.30%
# 4           244.0             Luanda        34,693    261.73         17.10%
# 18          229.0         Porto-Novo         6,476    110.71         -0.90%
# 26          226.0        Ouagadougou         3,418    106.58         -3.20%
# 27          257.0          Bujumbura           495    182.11         -0.70%
# 28          225.0       Yamoussoukro         9,674    111.61         -0.90%
# 31          237.0            Yaound�         8,291    118.65          2.50%
# 33          236.0             Bangui           297    186.86         37.10%
# 34          235.0          N'Djamena         1,016     117.7         -1.00%
# 38          269.0    Moroni, Comoros           202    103.62         -4.30%
# 39          242.0        Brazzaville         3,282    124.74          2.20%
# 45          243.0           Kinshasa         2,021    133.85          2.90%
# 53          240.0             Malabo         5,655    124.35          1.20%
# 54          291.0             Asmara           711       NaN            NaN
# 57          251.0        Addis Ababa        14,870    143.86         15.80%
# 61          241.0         Libreville         5,321    122.19          2.10%
# 62          220.0             Banjul           532    172.73          7.10%
# 69          224.0            Conakry         2,996    262.95          9.50%
# 70          245.0             Bissau           293    111.65          1.40%
# 96          231.0           Monrovia         1,386    223.13         23.60%
# 101         261.0       Antananarivo         3,905    184.33          5.60%
# 102         265.0           Lilongwe         1,298    418.34          9.40%
# 105         223.0             Bamako         3,179    108.73         -1.70%
# 108         222.0         Nouakchott         2,739    135.02          2.30%
# 117         258.0             Maputo         7,943    182.31          2.80%
# 125         227.0             Niamey         2,017    109.32         -2.50%
# 126         234.0              Abuja       120,369    267.51         11.40%
# 144         250.0             Kigali         1,115    151.09          3.40%
# 150         239.0              S����           121    185.09          7.90%
# 152         221.0              Dakar        10,902    109.25          1.80%
# 155         232.0           Freetown         1,093    234.16         14.80%
# 159         677.0            Honiara           169    133.06          1.60%
# 160         252.0          Mogadishu           645       NaN            NaN
# 163         211.0               Juba         1,727  4,583.71        187.90%
# 166         249.0           Khartoum        20,000  1,344.19         51.00%
# 171         992.0           Dushanbe         5,310    148.57          6.00%
# 172         255.0             Dodoma        11,973    187.43          3.50%
# 175         228.0               Lom�         3,000     113.3          0.70%
# 182         256.0            Kampala         5,680    173.87          2.90%
# 192         967.0              Sanaa        10,609    157.58          8.10%
# 193         260.0             Lusaka         5,141    212.31          9.20%
# 194         263.0             Harare        10,983    105.51          0.90%
#
#     Currency-Code  Fertility Rate Forested Area (%) Gasoline Price
# 0             AFN            4.47             2.10%         $0.70
# 4             AOA            5.52            46.30%         $0.97
# 18            XOF            4.84            37.80%         $0.72
# 26            XOF            5.19            19.30%         $0.98
# 27            BIF            5.41            10.90%         $1.21
# 28            XOF            4.65            32.70%         $0.93
# 31            XAF            4.57            39.30%         $1.03
# 33            NaN            4.72            35.60%         $1.41
# 34            XAF            5.75             3.80%         $0.78
# 38            KMF            4.21            19.70%            NaN
# 39            XAF            4.43            65.40%         $0.97
# 45            CDF            5.92            67.20%         $1.49
# 53            XAF            4.51            55.50%            NaN
# 54            ERN            4.06            14.90%         $2.00
# 57            ETB            4.25            12.50%         $0.75
# 61            XAF            3.97            90.00%         $0.92
# 62            GMD            5.22            48.40%         $1.18
# 69            GNF            4.70            25.80%         $0.90
# 70            XOF            4.48            69.80%            NaN
# 96            NaN            4.32            43.10%         $0.80
# 101           MGA            4.08            21.40%         $1.11
# 102           MWK            4.21            33.20%         $1.15
# 105           XOF            5.88             3.80%         $1.12
# 108           MRU            4.56             0.20%         $1.13
# 117           MZN            4.85            48.00%         $0.65
# 125           XOF            6.91             0.90%         $0.88
# 126           NGN            5.39             7.20%         $0.46
# 144           RWF            4.04            19.70%         $1.17
# 150           STN            4.32            55.80%            NaN
# 152           XOF            4.63            42.80%         $1.14
# 155           SLL            4.26            43.10%         $1.08
# 159           SBD            4.40            77.90%            NaN
# 160           SOS            6.07            10.00%         $1.41
# 163           SSP            4.70               NaN         $0.28
# 166           SDG            4.41             8.10%         $0.95
# 171           TJS            3.59             3.00%         $0.71
# 172           TZS            4.89            51.60%         $0.87
# 175           XOF            4.32             3.10%         $0.71
# 182           UGX            4.96             9.70%         $0.94
# 192           YER            3.79             1.00%         $0.92
# 193           ZMW            4.63            65.20%         $1.40
# 194           NaN            3.62            35.50%         $1.34

# %%
# Utilizando loc selecciona las columnas "Country" y "Capital/Major City" de las filas 
#donde el porcentaje de tierra agrícola (columna "Fertility Rate") es superior al 3.
data.loc[data['Fertility Rate'] > 3, ['Country', 'Capital/Major City']]
# Out:
#                               Country Capital/Major City
# 0                         Afghanistan              Kabul
# 2                             Algeria            Algiers
# 4                              Angola             Luanda
# 18                              Benin         Porto-Novo
# 26                       Burkina Faso        Ouagadougou
# 27                            Burundi          Bujumbura
# 28                        Ivory Coast       Yamoussoukro
# 31                           Cameroon            Yaound�
# 33           Central African Republic             Bangui
# 34                               Chad          N'Djamena
# 38                            Comoros    Moroni, Comoros
# 39              Republic of the Congo        Brazzaville
# 45   Democratic Republic of the Congo           Kinshasa
# 51                              Egypt              Cairo
# 53                  Equatorial Guinea             Malabo
# 54                            Eritrea             Asmara
# 57                           Ethiopia        Addis Ababa
# 61                              Gabon         Libreville
# 62                         The Gambia             Banjul
# 65                              Ghana              Accra
# 69                             Guinea            Conakry
# 70                      Guinea-Bissau             Bissau
# 80                               Iraq            Baghdad
# 82                             Israel          Jerusalem
# 88                              Kenya            Nairobi
# 89                           Kiribati       South Tarawa
# 91                         Kyrgyzstan            Bishkek
# 95                            Lesotho             Maseru
# 96                            Liberia           Monrovia
# 101                        Madagascar       Antananarivo
# 102                            Malawi           Lilongwe
# 105                              Mali             Bamako
# 107                  Marshall Islands             Majuro
# 108                        Mauritania         Nouakchott
# 111    Federated States of Micronesia            Palikir
# 117                        Mozambique             Maputo
# 119                           Namibia           Windhoek
# 125                             Niger             Niamey
# 126                           Nigeria              Abuja
# 131                          Pakistan          Islamabad
# 135                  Papua New Guinea       Port Moresby
# 144                            Rwanda             Kigali
# 148                             Samoa               Apia
# 150                      S�����������              S����
# 152                           Senegal              Dakar
# 155                      Sierra Leone           Freetown
# 159                   Solomon Islands            Honiara
# 160                           Somalia          Mogadishu
# 163                       South Sudan               Juba
# 166                             Sudan           Khartoum
# 171                        Tajikistan           Dushanbe
# 172                          Tanzania             Dodoma
# 174                        East Timor               Dili
# 175                              Togo               Lom�
# 176                             Tonga           Nuku����
# 182                            Uganda            Kampala
# 189                           Vanuatu          Port Vila
# 192                             Yemen              Sanaa
# 193                            Zambia             Lusaka
# 194                          Zimbabwe             Harare

# %%
data.iloc[: ,0:4]
# Out:
#      Unnamed: 0      Country Density\n(P/Km2) Abbreviation
# 0             0  Afghanistan               60           AF
# 1             1      Albania              105           AL
# 2             2      Algeria               18           DZ
# 3             3      Andorra              164           AD
# 4             4       Angola               26           AO
# ..          ...          ...              ...          ...
# 190         190    Venezuela               32           VE
# 191         191      Vietnam              314           VN
# 192         192        Yemen               56           YE
# 193         193       Zambia               25           ZM
# 194         194     Zimbabwe               38           ZW
#
# [195 rows x 4 columns]

# %%
data.head(5)
# Out:
#    Unnamed: 0      Country Density\n(P/Km2) Abbreviation  \
# 0           0  Afghanistan               60           AF
# 1           1      Albania              105           AL
# 2           2      Algeria               18           DZ
# 3           3      Andorra              164           AD
# 4           4       Angola               26           AO
#
#   Agricultural Land( %) Land Area(Km2)  Birth Rate  Calling Code  \
# 0                58.10%        652,230       32.49          93.0
# 1                43.10%         28,748       11.78         355.0
# 2                17.40%      2,381,741       24.28         213.0
# 3                40.00%            468        7.20         376.0
# 4                47.50%      1,246,700       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
# 2            Algiers       150,006  151.36          2.00%           DZD
# 3   Andorra la Vella           469     NaN            NaN           EUR
# 4             Luanda        34,693  261.73         17.10%           AOA
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 0            4.47             2.10%         $0.70
# 1            1.62            28.10%         $1.36
# 2            3.02             0.80%         $0.28
# 3            1.27            34.00%         $1.51
# 4            5.52            46.30%         $0.97

# %%
data.iloc[2,7]
# Out:
# 213.0

# %%
data.iloc[: , [0,2,5]]
# Out:
#      Unnamed: 0 Density\n(P/Km2) Land Area(Km2)
# 0             0               60        652,230
# 1             1              105         28,748
# 2             2               18      2,381,741
# 3             3              164            468
# 4             4               26      1,246,700
# ..          ...              ...            ...
# 190         190               32        912,050
# 191         191              314        331,210
# 192         192               56        527,968
# 193         193               25        752,618
# 194         194               38        390,757
#
# [195 rows x 3 columns]

# %% [markdown]
# # BONUS DE LOC Y ILOC
#
#     Encuentra el valor de "Gasoline Price" para el país cuya abreviatura es "AL" utilizando loc.
#
#     Selecciona todas las columnas para el país cuya capital es "Tirana" utilizando loc.
#
#     Filtra el conjunto de datos para mostrar solo las filas donde el índice de CPI (columna "CPI") sea igual a 128.85.
#
#     Encuentra la densidad (columna "Density\n(P/Km2)") para el país cuya abreviatura es "AD" utilizando loc.
#
#     Selecciona las columnas "Country" y "Co2-Emissions".
#
#     Filtra el conjunto de datos para mostrar solo las filas donde el índice de CPI cambió un 2% (columna "CPI Change (%)").
#
#     Encuentra la tasa de natalidad (columna "Birth Rate") para el país con la abreviatura "AF" utilizando loc.
#
#     Selecciona todas las columnas de las filas 3 a 5 (excluyendo la fila 5) utilizando iloc.
#
#     Selecciona las columnas 1, 3 y 6 para todas las filas utilizando iloc.

# %%
data.head(5)
# Out:
#    Unnamed: 0      Country Density\n(P/Km2) Abbreviation  \
# 0           0  Afghanistan               60           AF
# 1           1      Albania              105           AL
# 2           2      Algeria               18           DZ
# 3           3      Andorra              164           AD
# 4           4       Angola               26           AO
#
#   Agricultural Land( %) Land Area(Km2)  Birth Rate  Calling Code  \
# 0                58.10%        652,230       32.49          93.0
# 1                43.10%         28,748       11.78         355.0
# 2                17.40%      2,381,741       24.28         213.0
# 3                40.00%            468        7.20         376.0
# 4                47.50%      1,246,700       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
# 2            Algiers       150,006  151.36          2.00%           DZD
# 3   Andorra la Vella           469     NaN            NaN           EUR
# 4             Luanda        34,693  261.73         17.10%           AOA
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 0            4.47             2.10%         $0.70
# 1            1.62            28.10%         $1.36
# 2            3.02             0.80%         $0.28
# 3            1.27            34.00%         $1.51
# 4            5.52            46.30%         $0.97

# %%
data.loc[data['Abbreviation'] == 'AL', 'Gasoline Price']
# Out:
# 1    $1.36
# Name: Gasoline Price, dtype: object

# %%
data.loc[data['Capital/Major City'] == 'Tirana']
# Out:
#    Unnamed: 0  Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 1           1  Albania              105           AL                43.10%
#
#   Land Area(Km2)  Birth Rate  Calling Code Capital/Major City Co2-Emissions  \
# 1         28,748       11.78         355.0             Tirana         4,536
#
#       CPI CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 1  119.05          1.40%           ALL            1.62            28.10%
#
#   Gasoline Price
# 1         $1.36

# %%
data.loc[data['CPI'] == '128.85']
# Out:
#     Unnamed: 0     Country Density\n(P/Km2) Abbreviation  \
# 40          40  Costa Rica              100           CR
#
#    Agricultural Land( %) Land Area(Km2)  Birth Rate  Calling Code  \
# 40                34.50%         51,100       13.97         506.0
#
#    Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 40      San Jos������         8,023  128.85          2.10%           CRC
#
#     Fertility Rate Forested Area (%) Gasoline Price
# 40            1.75            54.60%         $0.98

# %%
data.loc[data['Abbreviation'] == 'AD', 'Density\n(P/Km2)']
# Out:
# 3    164
# Name: Density\n(P/Km2), dtype: object

# %%
data.loc[: ,['Abbreviation','Co2-Emissions']]
# Out:
#     Abbreviation Co2-Emissions
# 0             AF         8,672
# 1             AL         4,536
# 2             DZ       150,006
# 3             AD           469
# 4             AO        34,693
# ..           ...           ...
# 190           VE       164,175
# 191           VN       192,668
# 192           YE        10,609
# 193           ZM         5,141
# 194           ZW        10,983
#
# [195 rows x 2 columns]

# %%
data.loc[data['CPI Change (%)'] > '2%']
# Out:
#      Unnamed: 0      Country Density\n(P/Km2) Abbreviation  \
# 0             0  Afghanistan               60           AF
# 2             2      Algeria               18           DZ
# 6             6    Argentina               17           AR
# 10           10   Azerbaijan              123           AZ
# 11           11  The Bahamas               39           BS
# ..          ...          ...              ...          ...
# 189         189      Vanuatu               25           VU
# 190         190    Venezuela               32           VE
# 191         191      Vietnam              314           VN
# 192         192        Yemen               56           YE
# 193         193       Zambia               25           ZM
#
#     Agricultural Land( %) Land Area(Km2)  Birth Rate  Calling Code  \
# 0                  58.10%        652,230       32.49          93.0
# 2                  17.40%      2,381,741       24.28         213.0
# 6                  54.30%      2,780,400       17.02          54.0
# 10                 57.70%         86,600       14.00         994.0
# 11                  1.40%         13,880       13.97           1.0
# ..                    ...            ...         ...           ...
# 189                15.30%         12,189       29.60         678.0
# 190                24.50%        912,050       17.88          58.0
# 191                39.30%        331,210       16.75          84.0
# 192                44.60%        527,968       30.45         967.0
# 193                32.10%        752,618       36.19         260.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 0                Kabul         8,672     149.9          2.30%           AFN
# 2              Algiers       150,006    151.36          2.00%           DZD
# 6         Buenos Aires       201,348    232.75         53.50%           ARS
# 10                Baku        37,620    156.32          2.60%           AZN
# 11     Nassau, Bahamas         1,786    116.22          2.50%           NaN
# ..                 ...           ...       ...            ...           ...
# 189          Port Vila           147    117.13          2.80%           VUV
# 190            Caracas       164,175  2,740.27        254.90%           VED
# 191              Hanoi       192,668    163.52          2.80%           VND
# 192              Sanaa        10,609    157.58          8.10%           YER
# 193             Lusaka         5,141    212.31          9.20%           ZMW
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 0              4.47             2.10%         $0.70
# 2              3.02             0.80%         $0.28
# 6              2.26             9.80%         $1.10
# 10             1.73            14.10%         $0.56
# 11             1.75            51.40%         $0.92
# ..              ...               ...            ...
# 189            3.78            36.10%         $1.31
# 190            2.27            52.70%         $0.00
# 191            2.05            48.10%         $0.80
# 192            3.79             1.00%         $0.92
# 193            4.63            65.20%         $1.40
#
# [93 rows x 16 columns]
